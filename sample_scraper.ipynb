# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time

# Set up the Chrome webdriver (make sure you have Chrome and ChromeDriver installed)
driver = webdriver.Chrome()

# %%
url = 'https://www.google.com/travel/hotels'
driver.get(url)

# %%
search_bar = driver.find_element(By.CLASS_NAME, 'II2One')
search_bar.clear()
search_bar.send_keys('Kerala')

time.sleep(10)

# Create an ActionChains object and press the Enter key
actions = ActionChains(driver)
actions.send_keys(Keys.RETURN)
actions.perform()

# %%
# # Find and click the button by its aria-label
# button = driver.find_element(By.XPATH, "//button[@aria-label='All filters']")
# button.click()

# %%
# # Find the radio button within the section using the data-filtertype attribute
# section = driver.find_element(By.XPATH, "//section[@data-filtertype='22']")

# # Locate the radio button within the section
# radio_button = section.find_element(By.ID, "c170")  # Assuming the radio button is a child of the section

# # Click the radio button
# radio_button.click()

# %%
# # Find the radio button by its jsname attribute
# radio_button = driver.find_element(By.XPATH, "//input[@type='radio' and @jsname='YPqjbf']")
# radio_button.click()

# %%
# Find all <c-wiz> elements with the specific jsrenderer attribute
c_wiz_elements = driver.find_elements(By.XPATH, "//c-wiz[@jsrenderer='hAbFdb']")

# Iterate through the elements and extract their text or other data
for c_wiz in c_wiz_elements:
    # Extract the text or other data from the c-wiz element
    element_text = c_wiz.text
    print(element_text)
# Out:
# Elixir Hills - Suites Resort and Spa
# Sponsored·From Booking.com
# ₹11,209
# 4.6
# (9,644)
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Hot tub
# Fitness center
# Spa
# Restaurant
# View offer
# Taj Kumarakom Resort & Spa, Kerala
# Sponsored·From Taj Kumarakom Resort & Spa, Kerala
# ₹19,470
# 4.4
# (1,803)
# ·
# Eco-certified
# 5-star hotel
# Breakfast ($)
# Free Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Pet-friendly
# Fitness center
# Spa
# View offer
# Wayside Cottage | Private Rooms & Treehouse
# ₹1,264
# 4.2
# (144)
# Sleeps 13
# 4 bedrooms
# Fireplace
# Paid parking
# Free Wi-Fi
# No air conditioning
# No crib
# No elevator
# No fitness center
# View details
# VACATION RENTAL
# Vrindavanam Heritage Home
# ₹881
# 3.9
# (7)
# Villa
# Sleeps 10
# 6 bedrooms
# 6 bathrooms
# Air conditioning
# Free parking
# Free Wi-Fi
# No airport shuttle
# No beach access
# View details
# VACATION RENTAL
# Nettle Trees Farm Stay | Rooms & Restaurant
# ₹2,271
# 4.7
# (38)
# Sleeps 12
# 4 bedrooms
# Air conditioning
# Fireplace
# Kitchen
# Paid parking
# Free Wi-Fi
# No crib
# No elevator
# View details
# VACATION RENTAL
# Cliff and Coral
# ₹600
# 4.2
# (50)
# Sleeps 14
# 9 bedrooms
# Fireplace
# Cable TV
# Paid parking
# Free Wi-Fi
# No air conditioning
# No crib
# No elevator
# View details
# VACATION RENTAL
# Jungle Beats Resorts
# ₹6,045
# 4.8
# (2,306)
# 3-star hotel
# Free breakfast
# Wi-Fi
# Parking
# Air conditioning
# Restaurant
# Room service
# Airport shuttle
# Full-service laundry
# View prices
# Keekan Heritage Home - Bekal
# ₹448
# Sleeps 6
# 2 bedrooms
# 1 bathroom
# View details
# VACATION RENTAL
# Elephant Passage Resort
# DEAL
# ₹5,241
# 22% less than usual
# 4.6
# (1,453)
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Pool
# Fitness center
# Spa
# Restaurant
# Room service
# View prices
# DEAL
# Taj Bekal Resort & Spa, Kerala
# ₹29,229
# 4.6
# (3,935)
# ·
# Eco-certified
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Hot tub
# Air conditioning
# Fitness center
# Spa
# View prices
# Mountain Villa, Vagamon
# ₹7,840
# 4.7
# (185)
# Free breakfast
# Free Wi-Fi
# Free parking
# Pet-friendly
# Room service
# Full-service laundry
# Kid-friendly
# View prices
# Jungle Jive Tree House
# ₹5,799
# 4.1
# (188)
# 4-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Restaurant
# Kitchen in some rooms
# Airport shuttle
# Full-service laundry
# Kid-friendly
# View prices
# Arjun Munnar Inn Cottage (Cicily Cottage)
# ₹700
# 3.9
# (40)
# ·
# Excellent location
# Free Wi-Fi
# Parking
# Air conditioning
# Kitchen in some rooms
# Full-service laundry
# View prices
# Ragamaya Resort & Spa Munnar
# ₹8,333
# 4.4
# (1,554)
# 4-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Fitness center
# Spa
# Restaurant
# View prices
# Dream Catcher Plantation Resort
# DEAL
# ₹7,191
# 17% less than usual
# 4.3
# (2,828)
# 3-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Spa
# Restaurant
# Room service
# Full-service laundry
# View prices
# DEAL
# Eden Beach Villa
# GREAT DEAL
# ₹667
# 29% less than usual
# 5.0
# (30)
# View prices
# GREAT DEAL
# Seashore Homely Stay
# ₹897
# 4.1
# (284)
# Breakfast
# Free Wi-Fi
# Beach access
# Restaurant
# Kitchen in some rooms
# Airport shuttle
# Full-service laundry
# Kid-friendly
# View prices
# Rhythm Kumarakom
# ₹10,338
# 4.5
# (1,827)
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Fitness center
# Spa
# Restaurant
# View prices
# Black Pearl Beach Home
# ₹784
# 5.0
# (6)
# View prices
# Cocobay Resort
# ₹6,728
# 4.1
# (595)
# 3-star hotel
# Free breakfast
# Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Fitness center
# Spa
# Restaurant
# View prices
# Tea County Munnar
# ₹5,441
# 4.5
# (3,767)
# ·
# Excellent location
# 4-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Pool
# Spa
# Bar
# Restaurant
# Room service
# View prices
# Blanket Hotel & Spa | Luxury 5 Star Resorts in Munnar
# ₹8,848
# 4.7
# (2,580)
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Hot tub
# Air conditioning
# Fitness center
# Spa
# View prices
# Elephant Passage Resort
# Sponsored·From Booking.com
# ₹7,279
# 4.6
# (1,453)
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Pool
# Fitness center
# Spa
# Restaurant
# Room service
# View offer
# Hills and Hues Resorts Thekkady
# Sponsored·From Booking.com
# ₹17,824
# 4.9
# (3,327)
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Parking
# Outdoor pool
# Air conditioning
# Spa
# Restaurant
# Room service
# View offer

# %%
# for the ratings

ele=driver.find_elements(By.CLASS_NAME,'lA0BZ')
print(len(ele))
for i in ele:
    print(i.text)
# Out:
# 24
# 4.6
# 4.6
# 4.2
# 4.7
# 4.3
# 4.8
# 4.8
# 4.2
# 4.4
# 4.3
# 4.3
# 4.1
# 4.1
# 4.6
# 4.8
# 4.7
# 4.9
# 4.3
# 4.5
# 4.5
# 4.7
# 4.1
# 4.9
# 4.6

# %%
# for the hotel names

ele = driver.find_elements(By.CSS_SELECTOR,'.BgYkof.ogfYpf')
print(len(ele))
for i in ele:
    print(i.text)
# Out:
# 24
# Crowne Plaza Kochi
# Elixir Hills - Suites Resort and Spa
# Wayside Cottage | Private Rooms & Treehouse
# Thrill Holidays | Valley-view Rooms
# Koomankolly Heritage Retreat | Rooms & Guided Treks
# Jungle Beats Resorts
# Marari Umapathi Beach Villa - Deluxe Double Room
# Avondale Cottage | River-view Rooms
# Ragamaya Resort & Spa Munnar
# Club Mahindra Resort - Ashtamudi - Kerala
# Cliff & Coral
# Jungle Jive Tree House
# Boche Island - Kumbalangi
# Taj Bekal Resort & Spa, Kerala
# Tea Terrain Resorts and Spa
# The Fog Munnar Resorts and Spa
# PEKOE
# Le Sapphire Hotel & Restaurant
# Tea County Munnar
# Rhythm Kumarakom
# Serene Valley Resort by Stay vista
# Cocobay Resort
# Hills and Hues Resorts Thekkady
# Windermere Estate

# %%
# for extracting the features

ele = driver.find_elements(By.CLASS_NAME,'bX73z')
print(len(ele))
for i in ele:
    print(i.text)
# Out:
# 213
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Hot tub
# Air conditioning
# Fitness center
# Spa
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Hot tub
# Fitness center
# Spa
# Restaurant
# Sleeps 13
# 4 bedrooms
# Fireplace
# Paid parking
# Free Wi-Fi
# No air conditioning
# No crib
# No elevator
# No fitness center
# Sleeps 9
# 3 bedrooms
# Air conditioning
# Fireplace
# Paid parking
# Free Wi-Fi
# No crib
# No elevator
# No fitness center
# Sleeps 11
# 4 bedrooms
# Fireplace
# Paid parking
# No air conditioning
# No crib
# No elevator
# No fitness center
# No ironing board
# 3-star hotel
# Free breakfast
# Wi-Fi
# Parking
# Air conditioning
# Restaurant
# Room service
# Airport shuttle
# Full-service laundry
# House
# Sleeps 3
# 1 bedroom
# 1 bathroom
# 2 beds
# Air conditioning
# Crib
# Pet-friendly
# Washer
# Sleeps 9
# 3 bedrooms
# Fireplace
# Cable TV
# Paid parking
# Paid Wi-Fi
# No air conditioning
# No crib
# No elevator
# 4-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Fitness center
# Spa
# Restaurant
# 5-star hotel
# Breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Spa
# Restaurant
# Room service
# Breakfast ($)
# Free Wi-Fi
# Free parking
# Air conditioning
# Pet-friendly
# Restaurant
# Kitchen in some rooms
# Airport shuttle
# Full-service laundry
# 4-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Restaurant
# Kitchen in some rooms
# Airport shuttle
# Full-service laundry
# Kid-friendly
# 3-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Pet-friendly
# Spa
# Restaurant
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Hot tub
# Air conditioning
# Fitness center
# Spa
# Free breakfast
# Free Wi-Fi
# Free parking
# Pool
# Spa
# Restaurant
# Room service
# Kitchen in some rooms
# Full-service laundry
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Fitness center
# Spa
# Restaurant
# Free breakfast
# Free Wi-Fi
# Free parking
# Pool
# Restaurant
# Full-service laundry
# Free breakfast
# Free Wi-Fi
# Free parking
# Air conditioning
# Restaurant
# Room service
# Airport shuttle
# Full-service laundry
# Accessible
# 4-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Pool
# Spa
# Bar
# Restaurant
# Room service
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Fitness center
# Spa
# Restaurant
# Free breakfast
# Free Wi-Fi
# Free parking
# Pools
# Air conditioning
# Restaurant
# Room service
# Full-service laundry
# Kid-friendly
# 3-star hotel
# Free breakfast
# Wi-Fi
# Free parking
# Outdoor pool
# Air conditioning
# Fitness center
# Spa
# Restaurant
# 5-star hotel
# Free breakfast
# Free Wi-Fi
# Parking
# Outdoor pool
# Air conditioning
# Spa
# Restaurant
# Room service
# 3-star hotel
# Free breakfast
# Free Wi-Fi
# Free parking
# Outdoor pool
# Restaurant
# Room service
# Full-service laundry
# Kid-friendly

# %%
ele = driver.find_elements(By.CSS_SELECTOR,'.kixHKb.flySGb')
count = 0
for i in ele:
    if i.text != '':
        print(i.text)
        count += 1

print(count)
# Out:
# ₹9,794
# ₹11,209
# ₹2,431
# ₹4,370
# ₹2,604
# ₹5,723
# ₹1,685
# ₹1,056
# ₹7,290
# ₹7,681
# ₹763
# ₹5,799
# ₹5,544
# ₹17,545
# ₹7,166
# ₹6,800
# ₹6,048
# ₹2,004
# ₹5,613
# ₹10,323
# ₹6,575
# ₹6,715
# ₹17,824
# ₹14,160
# 24
